# %% [markdown]
# variables

# %%
a=2
b=3
c=a**2
d=c*b

print(d)
# Out:
# 12

# %%
#not valid variable names
#1age=21
full name='chinni'
#fname$ ='chin'
print(full name)
# Out:
#   Cell In[11], line 3
#     full name='chinni'
#          ^
# SyntaxError: invalid syntax

# %%
#valid variable names
age_1=22
full_name="chinni"
print(age_1)
# Out:
# 22

# %% [markdown]
# Datatypes
# 1.Mutable: able to change after variable creation
# 2.immutable: can't edit or alter once the variable is created

# %%
name="rachana chinni"  #can use single or double quotes for strings
print(name)
print(name.title()) #first letter is capital in every word
print(name.upper()) #all capital letters
print(name.lower()) #all small letters
# Out:
# rachana chinni
# Rachana Chinni
# RACHANA CHINNI
# rachana chinni
