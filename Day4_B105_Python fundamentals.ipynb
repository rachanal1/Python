# %% [markdown]
# List
#
# Collection of items in particular order
#
# immutable
#
# declared using square brackets []

# %%
students=['rachana','pujitha','chinni','rachu']
print(students)
# Out:
# ['rachana', 'pujitha', 'chinni', 'rachu']

# %%
type(students)
# Out:
# list

# %% [markdown]
# Indexing

# %%
print(students[2])
# Out:
# chinni

# %% [markdown]
# How to add, modify, and delete elements in list

# %%
students.append('lingutla')
print(students)
# Out:
# ['rachana', 'pujitha', 'chinni', 'rachu', 'lingutla']

# %%
students.insert(2,'prah')
print(students)
# Out:
# ['rachana', 'pujitha', 'prah', 'chinni', 'rachu', 'lingutla']

# %%
students[4]='ramadevi'
print(students)
# Out:
# ['rachana', 'pujitha', 'prah', 'chinni', 'ramadevi', 'lingutla']

# %%
#students.pop()  removes last element
del students[3]  #removes particular index element
print(students)
# Out:
# ['rachana', 'pujitha', 'prah', 'ramadevi', 'lingutla']
